# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X, y = datasets.load_iris(return_X_y=True)

# %%
X.shape, y.shape, np.unique(y)
# Out:
# ((150, 4), (150,), array([0, 1, 2]))

# %%
# take juste 2 features
X  = X[:, :2]
# Filter to have just X linked with class 0 and 1
X = X[(y == 0) | (y == 1)]
y = y[(y == 0) | (y == 1)]
# replace class in Perceptron by -1 and 1 labels
y[y == 0] = -1

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
def perceptron(X: np.ndarray, y: np.ndarray):
    n = y_train.shape[0]
    weight = np.zeros(X.shape[1])
    for i in range(n):
        if y[i] * np.dot(weight, X[i]) <= 0:
            weight += y[i] * X[i]
    return weight

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape, y_train.shape
# Out:
# ((75, 2), (75,))

# %%
weight = perceptron(X_train, y_train)

# %%
y_pred = X_test @ weight

# %%
# apply activation function tan when target are in [-1;1]
def tanh(x):
    e_p = np.exp(x)
    e_m = np.exp(-x)
    return (e_p - e_m) / (e_p + e_m)
# apply activation function sigmoid, relu when target are in [0;1]
def sigmoid(x):
    return 1/(1+np.exp(-x))
def relu(x):
    return np.maximum(0, x)

# %%
y_pred = np.vectorize(tanh)(y_pred)
y_pred = np.around(y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0
